# %%
# !pip install easyocr
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.9 MB 1.3 MB/s eta 0:00:03
#     --------------------------------------- 0.1/2.9 MB 544.7 kB/s eta 0:00:06
#    - -------------------------------------- 0.1/2.9 MB 751.6 kB/s eta 0:00:04
#    -- ------------------------------------- 0.2/2.9 MB 952.6 kB/s eta 0:00:03
#    --- ------------------------------------ 0.2/2.9 MB 1.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.3/2.9 MB 1.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.4/2.9 MB 1.1 MB/s eta 0:00:03
#    ------ --------------------------------- 0.5/2.9 MB 1.2 MB/s eta 0:00:03
#    ------ --------------------------------- 0.5/2.9 MB 1.2 MB/s eta 0:00:03
#    -------- ------------------------------- 0.6/2.9 MB 1.2 MB/s eta 0:00:02
# ...

# %%
import os
import easyocr

# Initialize the OCR reader
reader = easyocr.Reader(['en'])

def apply_ocr(image_path):
    """
    Apply OCR to extract text from an image.

    Args:
    - image_path: Path to the image file.

    Returns:
    - extracted_text: A string of the extracted text.
    """
    try:
        result = reader.readtext(image_path)
        extracted_text = " ".join([text for _, text, _ in result])
        return extracted_text
    except Exception as e:
        print(f"Error processing {image_path}: {e}")
        return ""

def process_image(image_path):
    """
    Process an individual image, applying OCR, and print the results.

    Args:
    - image_path: Path to the image file.
    """
    print(f"Processing image: {image_path}")
    extracted_text = apply_ocr(image_path)
    print(f"Extracted Text from {image_path}: {extracted_text}\n")

def traverse_directory(directory):
    """
    Traverse through the directory structure, processing each .png image found.

    Args:
    - directory: The root directory to start traversing from.
    """
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".png"):
                image_path = os.path.join(root, file)
                process_image(image_path)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open("IASA_Champ_Final/app_data/Bartender/1707227424\Bartender 5-1707227424.73.png")
plt.imshow(image)
plt.show()

# %% [markdown]
# The cell above displays the image. In the cell below, we can see the extracted text from the image.

# %%
# Example usage of an OCR

dataset_directory = "IASA_Champ_Final/app_data/Bartender/1707227424"
traverse_directory(dataset_directory)
# Out:
# Processing image: IASA_Champ_Final/app_data/Bartender/1707227424\Bartender 5-1707227424.73.png
# ...
